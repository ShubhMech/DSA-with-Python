# %%
def afunc(arr):
    
    if len(arr)>1:
        mid= len(arr)//2
#         print(mid,len(arr))
#         print("\n\n\n")
#         print(arr)
        l=arr[:mid]
        r=arr[mid:]
        afunc(l)
#         print("Pahle hisse pe aaye",l,r,arr)
        afunc(r)
#         print("Doosre hisse pe aaye",l,r,arr)
#         print(l,r,arr)
    
    
        
        i,j,k=0,0,0
        while i<len(l) and j<len(r):
            print(arr[i],arr[j])
            if l[i]<=r[j]:
        
                arr[k]= l[i]
                k +=1
                i +=1
            else:
                arr[k]= r[j]
                k +=1
                j +=1
#         print(arr)

        while i < len(l):

            arr[k] = l[i]

            k += 1

            i += 1

        while j < len(r):

            arr[k] = r[j]

            k += 1

            j += 1

        print("Array is: ", arr)
        print("L is:",l)

#         print(arr)

# %%
arr=[10,4,6,3,2,7,0,88,77,66,55,144,66,99,88,98,56,46,33,44,23,122,134,231,354,546,785,8905,8954,7543,86,84,45,58,87,89,95,98]

# %%
afunc(arr)
# Out:
# 10 10
# Array is:  [4, 10]
# L is: [10]
# 6 6
# Array is:  [3, 6]
# L is: [6]
# 10 10
# 3 4
# 4 4
# Array is:  [3, 4, 6, 10]
# L is: [4, 10]
# 2 2
# Array is:  [2, 7]
# L is: [2]
# 88 88
# Array is:  [77, 88]
# L is: [88]
# 0 0
# Array is:  [0, 77, 88]
# L is: [0]
# 2 2
# 0 7
# 2 2
# Array is:  [0, 2, 7, 77, 88]
# L is: [2, 7]
# 10 10
# 0 4
# 0 6
# 2 3
# 3 3
# 4 3
# 4 4
# Array is:  [0, 2, 3, 4, 6, 7, 10, 77, 88]
# L is: [3, 4, 6, 10]
# 66 66
# Array is:  [55, 66]
# L is: [66]
# 66 66
# Array is:  [66, 99]
# L is: [66]
# 144 144
# 66 66
# Array is:  [66, 99, 144]
# L is: [144]
# 66 66
# 55 55
# Array is:  [55, 66, 66, 99, 144]
# L is: [55, 66]
# 88 88
# Array is:  [88, 98]
# L is: [88]
# 46 46
# Array is:  [33, 46]
# L is: [46]
# 56 56
# 33 46
# Array is:  [33, 46, 56]
# L is: [56]
# 88 88
# 33 98
# 33 56
# Array is:  [33, 46, 56, 88, 98]
# L is: [88, 98]
# 66 66
# 33 55
# 33 144
# 46 55
# 46 56
# 55 56
# 56 56
# 56 66
# Array is:  [33, 46, 55, 56, 66, 66, 88, 98, 99, 144]
# L is: [55, 66, 66, 99, 144]
# 10 10
# 4 0
# 6 0
# 3 0
# 2 0
# 7 0
# 0 0
# 88 0
# 33 2
# 33 3
# 33 4
# 33 6
# 33 7
# 33 10
# 46 10
# Array is:  [0, 2, 3, 4, 6, 7, 10, 33, 46, 55, 56, 66, 66, 77, 88, 88, 98, 99, 144]
# L is: [0, 2, 3, 4, 6, 7, 10, 77, 88]
# 44 44
# Array is:  [23, 44]
# L is: [44]
# 122 122
# Array is:  [122, 134]
# L is: [122]
# 44 44
# 23 23
# Array is:  [23, 44, 122, 134]
# L is: [23, 44]
# 231 231
# Array is:  [231, 354]
# L is: [231]
# 785 785
# Array is:  [785, 8905]
# L is: [785]
# 546 546
# Array is:  [546, 785, 8905]
# L is: [546]
# 231 231
# 354 231
# Array is:  [231, 354, 546, 785, 8905]
# L is: [231, 354]
# 44 44
# 23 23
# 122 23
# 134 23
# Array is:  [23, 44, 122, 134, 231, 354, 546, 785, 8905]
# L is: [23, 44, 122, 134]
# 8954 8954
# Array is:  [7543, 8954]
# L is: [8954]
# 84 84
# Array is:  [45, 84]
# L is: [84]
# 86 86
# 45 84
# Array is:  [45, 84, 86]
# L is: [86]
# 8954 8954
# 45 7543
# 45 86
# Array is:  [45, 84, 86, 7543, 8954]
# L is: [7543, 8954]
# 58 58
# Array is:  [58, 87]
# L is: [58]
# 95 95
# Array is:  [95, 98]
# L is: [95]
# 89 89
# Array is:  [89, 95, 98]
# L is: [89]
# 58 58
# 87 58
# Array is:  [58, 87, 89, 95, 98]
# L is: [58, 87]
# 8954 8954
# 7543 45
# 58 58
# 84 58
# 86 58
# 86 84
# 86 86
# 86 87
# Array is:  [45, 58, 84, 86, 87, 89, 95, 98, 7543, 8954]
# L is: [45, 84, 86, 7543, 8954]
# 44 44
# 23 23
# 122 23
# 45 44
# 45 45
# 45 58
# 45 84
# 45 86
# 45 87
# 45 89
# 45 95
# 58 95
# 84 95
# 86 95
# 87 95
# 89 95
# 95 95
# 95 98
# Array is:  [23, 44, 45, 58, 84, 86, 87, 89, 95, 98, 122, 134, 231, 354, 546, 785, 7543, 8905, 8954]
# L is: [23, 44, 122, 134, 231, 354, 546, 785, 8905]
# 10 10
# 4 0
# 6 0
# 3 0
# 2 0
# 7 0
# 0 0
# 88 0
# 23 2
# 33 2
# 33 3
# 33 4
# 44 4
# 45 4
# 46 4
# 46 6
# 55 6
# 56 6
# 58 6
# 58 7
# 58 10
# 58 23
# 66 23
# 66 23
# 66 33
# 66 44
# 77 44
# 77 45
# 84 45
# 84 46
# 84 55
# Array is:  [0, 2, 3, 4, 6, 7, 10, 23, 33, 44, 45, 46, 55, 56, 58, 66, 66, 77, 84, 86, 87, 88, 88, 89, 95, 98, 98, 99, 122, 134, 144, 231, 354, 546, 785, 7543, 8905, 8954]
# L is: [0, 2, 3, 4, 6, 7, 10, 33, 46, 55, 56, 66, 66, 77, 88, 88, 98, 99, 144]

# %%
arr
# Out:
# [0,
#  2,
#  3,
#  4,
#  6,
#  7,
#  10,
#  23,
#  33,
#  44,
#  45,
#  46,
#  55,
#  56,
#  58,
#  66,
#  66,
#  77,
#  84,
#  86,
#  87,
#  88,
#  88,
#  89,
#  95,
#  98,
#  98,
#  99,
#  122,
#  134,
#  144,
#  231,
#  354,
#  546,
#  785,
#  7543,
#  8905,
#  8954]
